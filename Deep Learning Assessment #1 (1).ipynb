# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/sophia-szady/deeplearningait/blob/main/Deep%20Learning%20Assessment%20%231.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

image = img.imread('hungarian-puli-standing.jpg')
plt.imshow(image)
plt.show()

imageArray = np.array(image, dtype=np.uint8)
print(imageArray[:,0,0].size)
imageArray[:30,imageArray[0,:,0].size-30:,:] = [256,0,0]
plt.imshow(imageArray)
plt.show()
# Out:
# 667
